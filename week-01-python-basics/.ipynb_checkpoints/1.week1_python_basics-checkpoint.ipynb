# %% [markdown]
# # Week-1 Leraning Concepts :
#
# [1.Introduction to Python](#Introduction-to-PythonCreating-DataFrame)<br>
# [2.Data Types and Type Conversion in Python](#Data-Types-and-Type-Conversion-in-Python)<br>
# [3.Operators in Python](#Operators-in-Python)<br>
# [4.Flow Control](#Flow-Control)<br>
# [5.Input/Output Functions in Python](#Input/Output-Functions-in-Python)<br>

# %% [markdown]
# <a id="Introduction-to-PythonCreating-DataFrame"></a>
# ## Day-1
# ## **Introduction to Python**
#
# Python is a high-level, interpreted, interactive, and object-oriented programming language created by Guido van Rossum in 1991. It is designed to be easy to read and write, making it a great choice for beginners and professionals alike.
#
# Key Features of Python:
#
# **High-Level Language**
#
#  Python is a high-level language, meaning it abstracts away complex details (like memory management) and allows developers to focus on problem-solving rather than low-level operations.
#
# **Interpreted Language**
#
# Python is interpreted, meaning code is executed line by line (rather than compiled all at once). This makes debugging easier but can be slower than compiled languages like C++.
#
# **Interactive Language**
#
# Python supports an interactive mode, where you can write and execute code directly in the Python shell (REPL - Read-Eval-Print Loop), making it great for testing and learning.
#
# **Object-Oriented (OOP) Language**
#
# Python supports object-oriented programming (OOP), allowing developers to create classes and objects for structured and reusable code.
#
# **Dynamically Typed**
#
# Python does not require explicit variable type declarations (e.g., x = 10 instead of int x = 10), making it flexible but requiring careful type handling.
#
# **Extensive Standard Library**
#
# Python comes with a vast collection of built-in modules for tasks like file handling, web development, data science, and more.
#
# **Why Python is Popular?**
# Easy to learn and read (clean syntax).
#
# Cross-platform (works on Windows, macOS, Linux).
#
# Supports multiple programming paradigms (OOP, procedural, functional).
#
# Widely used in web development (Django, Flask), data science (Pandas, NumPy), AI/ML (TensorFlow, PyTorch), automation, and more.
#
# <a id="Data-Types-and-Type-Conversion-in-Python"></a>
# ## Day-2
#
# ## **Data Types and Type Conversion in Python**
#
# **1. Data Types in Python**
# Data types define the kind of value a variable can hold. Python has several built-in data types, categorized as:
#
# A. Numeric Types
# int (Integer): Whole numbers (e.g., 5, -10, 1000)
#
# float (Floating-point): Decimal numbers (e.g., 3.14, -0.001, 2.0)
#
# complex: Numbers with real and imaginary parts (e.g., 3 + 4j)
#
# B. Text Type
# str (String): Sequence of characters (e.g., "Hello", 'Python')
#
# C. Boolean Type
# bool: Represents True or False
#
# D. Sequence Types
# list: Ordered, mutable collection (e.g., [1, 2, 3])
#
# tuple: Ordered, immutable collection (e.g., (1, 2, 3))
#
# range: Sequence of numbers (e.g., range(5))
#
# E. Mapping Type
# dict (Dictionary): Key-value pairs (e.g., {"name": "Alice", "age": 25})
#
# F. Set Types
# set: Unordered, unique elements (e.g., {1, 2, 3})
#
# frozenset: Immutable version of set
#
# G. Binary Types
# bytes: Immutable sequence of bytes (e.g., b"Hello")
#
# bytearray: Mutable sequence of bytes
#
# memoryview: Memory view of an object
#
# **2. Type Conversion (Type Casting)**
# Type conversion refers to changing a value from one data type to another.
#
# A. Implicit Type Conversion (Automatic)
# Python automatically converts smaller data types to larger ones to avoid data loss.
#
# bool → int → float → complex

# %%
#Example for Implicit type Conversion
a = 5      # int  
b = 2.5    # float  
result = a + b  # result becomes float (7.5)  
print(result)  

#Output: 7.5 (Python converts int to float automatically)
# Out:
# 7.5

# %% [markdown]
# **B. Explicit Type Conversion (Manual)**
# We manually convert data types using functions like:
#
# int() → Converts to integer
#
# float() → Converts to float
#
# str() → Converts to string
#
# list() → Converts to list
#
# tuple() → Converts to tuple

# %%
#Examples:

# String to Integer  
num_str = "10"  
num_int = int(num_str)  
print(num_int + 5)  # 15  

# Float to Integer  
pi = 3.14  
int_pi = int(pi)  # Truncates decimal part  
print(int_pi)     # 3  

# Integer to String  
age = 25  
age_str = str(age)  
print("Age: " + age_str)  # "Age: 25"
# Out:
# 15
# 3
# Age: 25

# %% [markdown]
# **Variables in Python**
#
# Variables in Python are used to store data values. Unlike some other languages, Python does not require explicit declaration of variable types.
#
#  1. Variable Assignment

# %%
x = 10          # Integer  
name = "Alice"  # String  
is_active = True  # Boolean

# %% [markdown]
# 2. Variable Naming Rules
#
# Must start with a letter or underscore (_).
#
# Cannot start with a number.
#
# Can only contain letters, numbers, and underscores.
#
# Case-sensitive (age ≠ Age).
#
# 3. Local vs. Global Variables
# Local Variable: Defined inside a function (accessible only within that function).
#
# Global Variable: Defined outside a function (accessible everywhere).

# %%
#Example of Local Variable

def my_func():  
    local_var = 5  # Local variable  
    print(local_var)  

my_func()  # Output: 5  
print(local_var)  # ❌ Error (not accessible outside)
# Out:
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5     print(local_var)
#       7 my_func()  # Output: 5
# ----> 8 print(local_var)  # ❌ Error (not accessible outside)
#
# NameError: name 'local_var' is not defined

# %%
#Example of Global Variable

global_var = 10  # Global variable  

def my_func():  
    print(global_var)  # Accessible  

my_func()  # Output: 10  
print(global_var)  # Output: 10
# Out:
# 10
# 10

# %% [markdown]
# 4. Modifying a Global Variable Inside a Function
# By default, if you try to modify a global variable inside a function, Python treats it as a new local variable unless you use the global keyword.
#
# ❌ Without global (Creates a Local Variable Instead)

# %%
#Example
x = 10  # Global  

def modify():  
    x = 20  # New local variable (does not modify global x)  
    print("Inside function:", x)  

modify()  # Output: Inside function: 20  
print("Outside function:", x)  # Output: Outside function: 10 (unchanged)
# Out:
# Inside function: 20
# Outside function: 10

# %% [markdown]
# ✅ Using global (Modifies the Actual Global Variable)

# %%
x = 10  # Global  

def modify():  
    global x  # Declare x as global  
    x = 20    # Modifies the global x  
    print("Inside function:", x)  

modify()  # Output: Inside function: 20  
print("Outside function:", x)  # Output: Outside function: 20 (modified)
# Out:
# Inside function: 20
# Outside function: 20

# %% [markdown]
# 5. Avoiding global (Alternative Approach: Using Return Values)
# Instead of modifying a global variable directly, you can return the modified value and reassign it:

# %%
x = 10  # Global  

def modify(num):  
    num = 20  # Local modification  
    return num  

x = modify(x)  # Reassign the returned value  
print(x)  # Output: 20
# Out:
# 20

# %% [markdown]
# Key Takeaways
# Global variables can be accessed anywhere.
#
# To modify a global variable inside a function, use global.
#
# Without global, Python creates a new local variable instead.
#
# Best Practice: Avoid excessive use of global (use function parameters and return values instead).
#
# # Pactice Questions:
#
# Q1. What is the output of print(type(3.14))?
#
# Q2. Convert the string '50' to an integer and add 10 to it.
#
# Q3. What is the difference between = and ==?
#
# Q4. Create variables of each type — int, float, str, bool. Print the type of each.
#
# Q5. What happens when you run print("5" + 5)? Fix it.
#
# # Answers:

# %% [markdown]
# Q1 Answer: <class 'float'>
#
# Q2 Answer:

# %%
 x="50"
print(int(x)+10)
# Out:
# 60

# %% [markdown]
# Q3 Answer:
#
# `=` assigns a value to a variable. `==` checks if two values are equal.
#
# Q4 Answer:

# %%
a = 10
b = 3.14
c = "Hello"
d = True
print(type(a))   # <class 'int'>
print(type(b))   # <class 'float'>
print(type(c))   # <class 'str'>
print(type(d))   # <class 'bool'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Q5 Answer:
#
# It gives a TypeError.
#
# Fix:

# %%
print(int("5")+5)
# Out:
# 10

# %% [markdown]
# <a id="Operators-in-Python"></a>
#
# ## Day-3
#
# ## Operators in Python
#
# Operators are special symbols used to perform operations on variables and values. Python supports the following types of operators:
#
# 1. Arithmetic Operators
# Used for mathematical calculations.
#
#
# | Operator | Name            | Example   | Result |
# |----------|-----------------|-----------|--------|
# |   +      | Addition        | 5 + 3     | 8      |
# | -        | Subtraction     | 10 - 2    | 8      |
# | *        | Multiplication  | 4 * 3     | 12     |
# | /        | Division        | 10 / 2    | 5.0    |
# | %        | Modulus         | 10 % 3    | 3      |
# | **       | Exponentiation  | 2 ** 3    | 8      |
# | //       | Floor Division  | 10 // 3   | 3      |

# %%
#example
print(5 + 3)   # 8  
print(10 // 3) # 3 (discards remainder)  
print(2 ** 4)  # 16 (2^4)
# Out:
# 8
# 3
# 16

# %% [markdown]
# 2. Comparison (Relational) Operators
# Compare two values and return True or False.
#
#
# | Operator | Name                     | Example   | Result |
# |----------|--------------------------|-----------|--------|
# | ==       | Equal to                 | 5 == 5    | True   |
# | !=       | Not equal to             | 5 != 3    | True   |
# | >        | Greater than             | 10 > 5    | True   |
# | <        | Less than                | 5 < 10    | True   |
# | >=       | Greater than or equal    | 5 >= 5    | True   |
# | <=       | Less than or equal       | 4 <= 5    | True   |

# %%
x = 10  
print(x > 5)   # True  
print(x == 10) # True  
print(x != 20) # True
# Out:
# True
# True
# True

# %% [markdown]
# 3. Logical Operators
# Combine conditional statements (and, or, not).
#
# | Operator | Description                         | Example              | Result |
# |----------|-------------------------------------|----------------------|--------|
# | and      | True if both are true               | (5 > 3) and (2 < 4)  | True   |
# | or       | True if at least one is true        | (5 > 3) or (2 > 4)   | True   |
# | not      | Reverses the result (True→False)    | not(5 > 3)           | False  |

# %%
age = 25  
print(age > 18 and age < 30)  # True  
print(age < 18 or age == 25)  # True  
print(not age == 25)          # False
# Out:
# True
# True
# False

# %% [markdown]
# 4. Assignment Operators
# Assign values to variables.
#
# | Operator | Example      | Equivalent to    |
# |----------|--------------|------------------|
# | =        | x = 5        | x = 5            |
# | +=       | x += 3       | x = x + 3        |
# | -=       | x -= 2       | x = x - 2        |
# | *=       | x *= 4       | x = x * 4        |
# | /=       | x /= 2       | x = x / 2        |
# | %=       | x %= 3       | x = x % 3        |
# | **=      | x **= 2      | x = x ** 2       |
# | //=      | x //= 2      | x = x // 2       |

# %%
x = 10  
x += 5  # x = 15  
x *= 2  # x = 30  
print(x)  # 30
# Out:
# 30

# %% [markdown]
# 5. Membership Operators
# Check if a value exists in a sequence (in, not in).
#
# | Operator | Description                       | Example                | Result |
# |----------|-----------------------------------|------------------------|--------|
# | in       | True if value exists              | "a" in "apple"         | True   |
# | not in   | True if value does not exist      | 10 not in [1, 2, 3]    | True   |

# %%
fruits = ["apple", "banana", "cherry"]  
print("banana" in fruits)     # True  
print("mango" not in fruits)  # True
# Out:
# True
# True

# %% [markdown]
# 6. Identity Operators
# Compare memory locations of objects (is, is not).
#
#
# | Operator | Description                    | Example       | Result              |
# |----------|--------------------------------|---------------|---------------------|
# | is       | True if same object            | x is y        | Depends             |
# | is not   | True if not same object        | x is not y    | Depends             |

# %%
a = [1, 2, 3]  
b = a  
c = [1, 2, 3]  

print(a is b)      # True (same object)  
print(a is c)      # False (different objects)  
print(a == c)      # True (same values)
# Out:
# True
# False
# True

# %% [markdown]
# # Pactice Questions:
#
# Q1. What is 15 % 4?
#
# Q2. What is 2 ** 8?
#
# Q3. What does (True and False) or (not False) evaluate to?
#
# Q4. What is the result of 2 + 3 ** 2 * 4? (Apply operator precedence)
#
# Q5. Write code to check if a number is between 10 and 50 inclusive using a single expression.
#
# Q6. x = 10. After x **= 3, what is x?
#
# Q7. Without running, predict the output: x = 5; x += 3; x **= 2; x //= 4; print(x)
#
# Q8. Write a program that prints whether a number is divisible by both 3 AND 5.
#
# # Answers:
#
# Q1 Answer: 3 (15 ÷ 4 = 3 remainder 3)
#
# Q2 Answer: 256 ( 2 ** 8 it means 2 power 8)
#
# Q3 Answer: False or True = True
#
# Q4 Answer: 2 + 9 * 4 = 2 + 36 = 38
#
# Q5 Answer:

# %%
num = 25
print(10 <= num <= 50)   # True
# Out:
# True

# %% [markdown]
# Q6 Answer: 1000
#
# Q7 Answer: 16
#
# Q8 Answer:

# %%
num = 15
print(num % 3 == 0 and num % 5 == 0)   # True
# Out:
# True

# %% [markdown]
# <a id="Flow-Control"></a>
#
# ## Day-4
#
# ## Flow Control
#
#
#  Flow control includes decision-making (like if, elif, else) and looping (like for, while).
#
# - Decision-making → Executes code based on conditions.
#
# - Looping → Repeats code until a condition is met.
#
# #### **1. Decision-Making in Python (if, elif, else)**
#
#
# Used to execute code only if certain conditions are true.
#
# #### A. if Statement
# Checks a condition.
#
# Executes code only if the condition is True.
#
# Syntax:
#
# if condition:
#
#      Code to execute if condition is True

# %%
#Example: 

age = 18  
if age >= 18:  
    print("You are an adult.")
# Out:
# You are an adult.

# %% [markdown]
# #### B. elif (Else If) Statement
#
# - Used when there are multiple conditions to check.
#
# - Only runs if the previous conditions were False.
#
# Syntax:
#
# if condition1:
#
#      Code if condition1 is True
# elif condition2:
#
#      Code if condition2 is True (but condition1 was False)

# %%
marks = 75  

if marks >= 90:  
    print("Grade: A")  
elif marks >= 80:  
    print("Grade: B")  
elif marks >= 70:  
    print("Grade: C")
# Out:
# Grade: C

# %% [markdown]
# C. else Statement
#
# - Runs only if all previous conditions were False.
#
# - Acts as a default case.
#
# Syntax:
#
# if condition1:
#
#      Code if condition1 is True
# else:
#
#      Code if all above conditions were False

# %%
age = 15  

if age >= 18:  
    print("You can vote.")  
else:  
    print("You cannot vote yet.")
# Out:
# You cannot vote yet.

# %% [markdown]
# #### 2. Combining if, elif, and else
#
# You can use all three together for complex decision-making.

# %%
# Example: 
num = 0  

if num > 0:  
    print("Positive")  
elif num < 0:  
    print("Negative")  
else:  
    print("Zero")
# Out:
# Zero

# %% [markdown]
# Where Do We Use Flow Control?
#
# User Input Validation

# %%
password = input("Enter password: ")  
if password == "secret123":  
    print("Access granted!")  
else:  
    print("Access denied!")
# Out:
# Enter password:  12sctr
# Access denied!

# %% [markdown]
# Game Logic (e.g., checking player health)
#
# Automated Decisions (e.g., filtering data, grading systems)
#
# Error Handling (e.g., checking if a file exists before opening)
#
# Key Takeaways
#
# - Flow Control = Decision-making (if, elif, else) + Loops (for, while).
# - if → Runs code if condition is True.
# - elif → Checks another condition if the first was False.
# - else → Runs if all conditions were False.
# - Used in input validation, automation, gaming, data filtering, etc.
#
# # Pactice
#
# ## Task 1 — Even or Odd
# ### Check if a number is even or odd.

# %%
# Answer
n=5
if n%2==0:
    print(f"{n} is Evem")
else: 
    print(f"{n} is Odd")
# Out:
# 5 is Odd

# %% [markdown]
# ## Task 2 — Fever Check
# ### temp = 38.5 → print "Fever" if above 37, else "Normal".

# %%
# Answer
temp = 38.5
if temp > 37:
    print("Fever")
else:
    print("Normal")
# Out:
# Fever

# %% [markdown]
# ## Task 3 — Day of the Week
# ### Number 1–7 → print day name. Outside range → "Invalid input".

# %%
# Answer
day_num = 3
if day_num == 1:
    print("Monday")
elif day_num == 2:
    print("Tuesday")
elif day_num == 3:
    print("Wednesday")
elif day_num == 4:
    print("Thursday")
elif day_num == 5:
    print("Friday")
elif day_num == 6:
    print("Saturday")
elif day_num == 7:
    print("Sunday")
else:
    print("Invalid input")
# Out:
# Wednesday

# %% [markdown]
# ### Task 4 — Leap Year Checker

# %%
# Answer
year = 2024
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a Leap Year")
else:
    print(f"{year} is NOT a Leap Year")
# Out:
# 2024 is a Leap Year

# %% [markdown]
# ## Task 5 — Full Grade Calculator
# ### Marks → grade with invalid input handling.

# %%
# Answer
marks = 75
if marks < 0 or marks > 100:
    print("Invalid marks")
elif marks >= 90:
    print(f"Marks: {marks} | Grade: A+")
elif marks >= 80:
    print(f"Marks: {marks} | Grade: A")
elif marks >= 70:
    print(f"Marks: {marks} | Grade: B")
elif marks >= 60:
    print(f"Marks: {marks} | Grade: C")
elif marks >= 50:
    print(f"Marks: {marks} | Grade: D")
else:
    print(f"Marks: {marks} | Grade: F - Fail")
# Out:
# Marks: 75 | Grade: B

# %% [markdown]
# <a id="Input/Output-Functions-in-Python"></a>
#
# ## Day 5
#
# ## Input/Output Functions in Python
#
# Input/Output (I/O) is how your program **talks to the user**.
#
# - **Input** → User gives data to the program (`input()`)
# - **Output** → Program shows results to the user (`print()`)
#
# > 💡 **Real-life analogy:** Input is like typing your name at an ATM. Output is the ATM showing your balance on screen.
#
# 1. The `print()` Function — Output
#
# Used to **display information** on the screen.
#
# **Syntax:**
# ```python
# print(value1, value2, ...)
# ```

# %%
# Example
print("Hello, World!")
print("My name is", "Alice", "and I am", 25, "years old.")
# Out:
# Hello, World!
# My name is Alice and I am 25 years old.

# %% [markdown]
# #### A. print() with sep parameter
#
# `sep` controls what goes **between** multiple values. Default is a space `" "`.
#
# **Syntax:**
#
# print(value1, value2, sep="separator")

# %%
# Example
print(2024, 1, 15, sep="-")                     # date format
print("apple", "banana", "cherry", sep=" | ")
# Out:
# 2024-1-15
# apple | banana | cherry

# %% [markdown]
# B. print() with end parameter
#
# `end` controls what comes **after** the output. Default is a new line `"\n"`.
#
# **Syntax:**
# ```python
# print(value, end="something")

# %%
# Example
print("Hello", end=" ")   # stays on same line
print("World!")

print("Loading...", end=" ")
print("Done!")
# Out:
# Hello World!
# Loading... Done!

# %% [markdown]
# #### 2. The `input()` Function — Input
#
# Used to **take data from the user** while the program is running.
#
# ⚠️ **Important:** `input()` always returns a **string**, even if the user types a number!
#
# **Syntax:**
#
# variable = input("Message to show user: ")

# %%
# Example
name = input("Enter your name: ")
print("Hello,", name)
# Out:
# Enter your name:  Ramana
# Hello, Ramana

# %% [markdown]
# #### A. Converting Input to a Number
#
# Since `input()` returns a string, you must **convert it** to do math.
#
# **Syntax:**
#
# age = int(input("Enter age: "))        # converts to integer
#
# price = float(input("Enter price: "))  # converts to float

# %%
# Without conversion — WRONG
num = input("Enter a number: ")
print(num + 10)     # ← ERROR! can't add string and int
# Out:
# Enter a number:  5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Without conversion — WRONG
#       2 num = input("Enter a number: ")
# ----> 3 print(num + 10)     # ← ERROR! can't add string and int
#
# TypeError: can only concatenate str (not "int") to str

# %%
# With conversion — CORRECT
num = int(input("Enter a number: "))
print(num + 10)     # Works!
# Out:
# Enter a number:  50
# 60

# %% [markdown]
# #### 3. f-Strings — Formatted Output (Most Used!)
#
# f-strings let you **embed variables directly inside a string**.
#
# **Syntax:**
#
# f"text {variable} text"
#
#
# > 💡 Put `f` before the quote, then use `{}` to insert any variable or expression

# %%
name = "Alice"
age = 25

# Old way — using +
print("My name is " + name + " and I am " + str(age) + " years old.")

# Better way — using ,
print("My name is", name, "and I am", age, "years old.")

# Best way — f-string
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Alice and I am 25 years old.
# My name is Alice and I am 25 years old.
# My name is Alice and I am 25 years old.

# %% [markdown]
# #### A. f-String with Expressions
#
# You can do **calculations directly inside** `{}`.

# %%
# Example
price = 100
tax = 18
print(f"Price: {price}, Tax: {tax}, Total: {price + tax}")

num = 5
print(f"{num} squared is {num ** 2}")
# Out:
# Price: 100, Tax: 18, Total: 118
# 5 squared is 25

# %% [markdown]
# #### B. f-String Number Formatting
#
# Control how numbers look inside f-strings.
#
# **Syntax:**
# ```python
# f"{value:.2f}"   # 2 decimal places
# f"{value:,}"     # comma separator for thousands
# f"{value:.2f}%"  # percentage format

# %%
# Example
pi = 3.14159
salary = 50000
percentage = 87.5

print(f"Pi is {pi:.2f}")                   # 2 decimal places
print(f"Salary: {salary:,}")               # comma separator
print(f"Percentage: {percentage:.2f}%")    # 2 decimals + %
# Out:
# Pi is 3.14
# Salary: 50,000
# Percentage: 87.50%

# %% [markdown]
# ## 4. Input Validation
#
# Always check if the user gave **correct input** before using it.
# Combine `input()` with `if/else`.

# %%
# Example
age = int(input("Enter your age: "))

if age < 0 or age > 120:
    print("Invalid age!")
elif age >= 18:
    print(f"You are {age} years old. You are an adult.")
else:
    print(f"You are {age} years old. You are a minor.")
# Out:
# Enter your age:  25
# You are 25 years old. You are an adult.

# %% [markdown]
# #### 5. Taking Multiple Inputs in One Line
#
# Use `split()` to take multiple values at once.
#
# **Syntax:**
#
# a, b = input("Enter two numbers: ").split()

# %%
# Example — user types: 10 20
a, b = input("Enter two numbers separated by space: ").split()
a = int(a)
b = int(b)
print(f"Sum of {a} and {b} is {a + b}")
# Out:
# Enter two numbers separated by space:  50 60
# Sum of 50 and 60 is 110

# %% [markdown]
# ## Task 1 — Greeting Program
# ### Ask name and city → print "Hello Alice! You are from Mumbai."

# %%
# Answer
name = input("Enter your name: ")
city = input("Enter your city: ")
print(f"Hello {name}! You are from {city}.")
# Out:
# Enter your name:  Alice
# Enter your city:  Lolla
# Hello Alice! You are from Lolla.

# %% [markdown]
# ## Task 2 — Simple Calculator
# ### Two numbers → print sum, difference, product, division (2 decimal places).

# %%
# Answer
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print(f"Sum        : {a + b}")
print(f"Difference : {a - b}")
print(f"Product    : {a * b}")
print(f"Division   : {a / b:.2f}")
# Out:
# Enter first number:  5
# Enter second number:  6
# Sum        : 11.0
# Difference : -1.0
# Product    : 30.0
# Division   : 0.83

# %% [markdown]
# ## Task 3 — Bill Generator
# ### Product name, price, quantity → formatted bill.

# %%
# Answer
product = input("Enter product name: ")
price = float(input("Enter price: "))
quantity = int(input("Enter quantity: "))
total = price * quantity
print("---------- BILL ----------")
print(f"Item     : {product}")
print(f"Price    : {price}")
print(f"Quantity : {quantity}")
print(f"Total    : {total}")
print("--------------------------")
# Out:
# Enter product name:  Ramana
# Enter price:  50
# Enter quantity:  2
# ---------- BILL ----------
# Item     : Ramana
# Price    : 50.0
# Quantity : 2
# Total    : 100.0
# --------------------------

# %% [markdown]
# ## Task 4 — Percentage Validator
# ### Percentage input → Excellent / Good / Average / Needs Improvement / Invalid.

# %%
# Answer
percentage = float(input("Enter percentage: "))
if percentage < 0 or percentage > 100:
    print("Invalid percentage")
elif percentage >= 90:
    print(f"{percentage}% — Excellent!")
elif percentage >= 70:
    print(f"{percentage}% — Good!")
elif percentage >= 50:
    print(f"{percentage}% — Average")
else:
    print(f"{percentage}% — Needs Improvement")
# Out:
# Enter percentage:  70.04
# 70.04% — Good!

# %% [markdown]
# ## Task 5 — User Profile Card
# ### Name, age, job, salary → formatted card with ternary for status.

# %%
# Answer
name = input("Enter name: ")
age = int(input("Enter age: "))
job = input("Enter job: ")
salary = int(input("Enter salary: "))
status = "Adult" if age >= 18 else "Minor"
print("========== PROFILE ==========")
print(f"Name   : {name}")
print(f"Age    : {age}")
print(f"Job    : {job}")
print(f"Salary : {salary:,}")
print(f"Status : {status}")
print("=============================")
# Out:
# Enter name:  Ramana
# Enter age:  24
# Enter job:  Data Analyst
# Enter salary:  50000
# ========== PROFILE ==========
# Name   : Ramana
# Age    : 24
# Job    : Data Analyst
# Salary : 50,000
# Status : Adult
# ...

# %% [markdown]
# ## Task 6 — Registration Form with Validation
# ### Username (not empty) + age (1–120) + email (must have @) → validate all three.

# %%
# Answer
username = input("Enter username: ")
age = int(input("Enter age: "))
email = input("Enter email: ")
if username == "":
    print("Invalid: Username cannot be empty")
elif age < 1 or age > 120:
    print("Invalid: Age must be between 1 and 120")
elif "@" not in email:
    print("Invalid: Email must contain @")
else:
    print(f"Welcome {username}! Age: {age} | Email: {email}")
    print("Registration successful!")
# Out:
# Enter username:  ramana@gmail.com
# Enter age:  22
# Enter email:  r@gmail.com
# Welcome ramana@gmail.com! Age: 22 | Email: r@gmail.com
# Registration successful!

# %% [markdown]
# ## Day-6,7
#
# in Day 6 Make Reveison on Entire Week-1 comcepts and Day-7 Do Practice on Week-1 Concepts in Hacker Rank hacker rank questions in `week1_practice_problems.ipynb`
